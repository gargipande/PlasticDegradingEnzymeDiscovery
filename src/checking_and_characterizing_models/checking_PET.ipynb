# %%
import pandas as pd

# %%
df_performances = pd.read_csv("../../results_training_exploring/PET/explored_performances.csv")
df_selected = pd.read_csv("../../results_training_exploring/PET/selected_models_for_tuning.csv")

df_merge = df_selected.merge(right=df_performances, left_on=['Algorithm','Encoder'], right_on=["algorithm", "encoder"])
df_merge.columns
# Out:
# Index(['Algorithm', 'Encoder', 'mean_accuracy_training_x',
#        'mean_f_score_training_x', 'mean_precision_training_x',
#        'mean_recall_training_x', 'mean_accuracy_testing_x',
#        'mean_f_score_testing_x', 'mean_precision_testing_x',
#        'mean_recall_testing_x', 'mean_accuracy_testing_y',
#        'mean_f_score_testing_y', 'mean_precision_testing_y',
#        'mean_recall_testing_y', 'mean_accuracy_training_y',
#        'mean_f_score_training_y', 'mean_precision_training_y',
#        'mean_recall_training_y', 'Voting', 'algorithm', 'fit_time',
#        'score_time', 'F1_cv', 'recall_cv', 'precision_cv', 'accuracy_cv',
#        'accuracy_val', 'precision_val', 'recall_val', 'f1_val',
#        'matthews_corrcoef_val', 'sensitivity', 'specificity', 'encoder',
#        'Strategy'],
#       dtype='object')

# %%
df_merge = df_merge[['Algorithm', 'Encoder', 'F1_cv', 'recall_cv', 'precision_cv', 'accuracy_cv',
       'accuracy_val', 'precision_val', 'recall_val', 'f1_val', 'matthews_corrcoef_val', 'sensitivity', 'specificity', 'Strategy']]

df_merge.head(5)
# Out:
#             Algorithm       Encoder     F1_cv  recall_cv  precision_cv  \
# 0  AdaBoostClassifier  protrans_bdf  0.921062   0.921157      0.921705
# 1  AdaBoostClassifier  protrans_bdf  0.903378   0.903799      0.909573
# 2  AdaBoostClassifier  protrans_bdf  0.914245   0.914436      0.917450
# 3  AdaBoostClassifier  protrans_bdf  0.931453   0.931560      0.934710
# 4  AdaBoostClassifier  protrans_bdf  0.907222   0.907481      0.911704
#
#    accuracy_cv  accuracy_val  precision_val  recall_val    f1_val  \
# 0     0.921157      0.891892       0.923077    0.878049  0.900000
# 1     0.903799      0.905405       0.891892    0.916667  0.904110
# 2     0.914436      0.972973       0.977273    0.977273  0.977273
# 3     0.931560      0.959459       0.942857    0.970588  0.956522
# 4     0.907481      0.945946       0.945946    0.945946  0.945946
#
#    matthews_corrcoef_val  sensitivity  specificity         Strategy
# 0               0.783672     0.878049     0.909091  Embedding-based
# 1               0.811107     0.916667     0.894737  Embedding-based
# 2               0.943939     0.977273     0.966667  Embedding-based
# 3               0.918901     0.970588     0.950000  Embedding-based
# 4               0.891892     0.945946     0.945946  Embedding-based

# %%
grouped_data = df_merge.groupby(by=['Algorithm', 'Encoder']).mean(numeric_only=True).sort_values(by="matthews_corrcoef_val", ascending=False).reset_index()

# %%
grouped_std = df_merge.groupby(by=['Algorithm', 'Encoder']).std(numeric_only=True).sort_values(by="matthews_corrcoef_val", ascending=False).reset_index()

# %%
grouped_data = grouped_data[["Algorithm", "Encoder", "accuracy_val", "precision_val", "recall_val", "f1_val", "matthews_corrcoef_val", "sensitivity", "specificity"]]
grouped_std = grouped_std[["Algorithm", "Encoder", "accuracy_val", "precision_val", "recall_val", "f1_val", "matthews_corrcoef_val", "sensitivity", "specificity"]]
grouped_std.columns = ["Algorithm", "Encoder", "std_accuracy_val", "std_precision_val", "std_recall_val", "std_f1_val", "std_matthews_corrcoef_val", "std_sensitivity", "std_specificity"]

# %%
merge_data = grouped_data.merge(right=grouped_std, on=["Algorithm", "Encoder"])
merge_data
# Out:
#                          Algorithm          Encoder  accuracy_val  \
# 0              ExtraTrees-ensemble   protrans_xlu50      0.947297
# 1              ExtraTrees-ensemble             esme      0.944595
# 2        GaussianProcessClassifier     protrans_bdf      0.941892
# 3                   LGBMClassifier    protrans_bert      0.941892
# 4               LogisticRegression     protrans_bdf      0.941892
# 5   HistGradientBoostingClassifier    protrans_bert      0.939189
# 6                   LGBMClassifier            esm1b      0.939189
# 7                              SVC   protrans_xlu50      0.937838
# 8              ExtraTrees-ensemble            esm1b      0.937838
# 9               LogisticRegression            esm1b      0.937838
# 10                 RidgeClassifier     protrans_bdf      0.936486
# 11                 RidgeClassifier    protrans_bert      0.936486
# 12             ExtraTrees-ensemble  protrans_albert      0.935135
# 13              LogisticRegression  protrans_albert      0.935135
# 14                  LGBMClassifier             esme      0.935135
# 15      GradientBoostingClassifier    protrans_bert      0.933784
# 16                  LGBMClassifier   protrans_xlu50      0.933784
# 17                   XGBClassifier  protrans_albert      0.933784
# 18             ExtraTrees-ensemble    protrans_bert      0.932432
# 19                   XGBClassifier            esm1b      0.932432
# 20                 RidgeClassifier   protrans_xlu50      0.932432
# 21              AdaBoostClassifier     protrans_bdf      0.932432
# 22                   XGBClassifier    protrans_bert      0.932432
# 23               BaggingClassifier   protrans_xlu50      0.928378
#
#     precision_val  recall_val    f1_val  matthews_corrcoef_val  sensitivity  \
# 0        0.950247    0.941725  0.945064               0.895236     0.941725
# 1        0.953096    0.934603  0.942308               0.890885     0.934603
# 2        0.928998    0.957015  0.941603               0.885454     0.957015
# 3        0.940419    0.942039  0.940096               0.884849     0.942039
# 4        0.942590    0.940846  0.940945               0.884222     0.940846
# 5        0.934601    0.942519  0.937478               0.879423     0.942519
# 6        0.936616    0.940178  0.937570               0.879100     0.940178
# 7        0.934954    0.939095  0.935803               0.876818     0.939095
# 8        0.949279    0.922948  0.934775               0.876733     0.922948
# 9        0.930043    0.945558  0.936842               0.876490     0.945558
# 10       0.925017    0.947997  0.935452               0.873968     0.947997
# 11       0.934301    0.937880  0.935279               0.873342     0.937880
# 12       0.946749    0.921177  0.932688               0.871265     0.921177
# 13       0.938734    0.929596  0.933191               0.871012     0.929596
# 14       0.935521    0.931125  0.932658               0.870697     0.931125
# 15       0.940853    0.924693  0.931826               0.868432     0.924693
# 16       0.940628    0.923394  0.931093               0.868251     0.923394
# 17       0.953993    0.907706  0.929669               0.867893     0.907706
# 18       0.951810    0.911321  0.929894               0.866779     0.911321
# 19       0.933439    0.929191  0.930272               0.865877     0.929191
# 20       0.927365    0.936581  0.930870               0.865723     0.936581
# 21       0.925961    0.937776  0.931010               0.865567     0.937776
# 22       0.940820    0.920355  0.929888               0.864916     0.920355
# 23       0.935911    0.919621  0.926589               0.857957     0.919621
#
#     specificity  std_accuracy_val  std_precision_val  std_recall_val  \
# 0      0.952137          0.024216           0.034597        0.046344
# 1      0.955270          0.019583           0.039155        0.049276
# 2      0.928291          0.021176           0.043068        0.038743
# 3      0.941631          0.023878           0.042199        0.042719
# 4      0.944131          0.028525           0.041751        0.037345
# 5      0.936702          0.026458           0.041710        0.046106
# 6      0.939327          0.026458           0.035911        0.043149
# 7      0.936399          0.031979           0.047393        0.049028
# 8      0.952567          0.025640           0.040170        0.049124
# 9      0.930464          0.026420           0.037386        0.044229
# 10     0.925559          0.031883           0.044913        0.045569
# 11     0.935571          0.029913           0.032827        0.049801
# 12     0.949434          0.023665           0.033758        0.049352
# 13     0.942460          0.028346           0.046258        0.039706
# 14     0.939499          0.026111           0.032062        0.043976
# 15     0.944989          0.029504           0.042418        0.043599
# 16     0.944989          0.031499           0.043265        0.045684
# 17     0.957112          0.018518           0.031333        0.038558
# 18     0.954840          0.025481           0.035637        0.050267
# 19     0.936493          0.022969           0.030742        0.049975
# 20     0.927863          0.029193           0.045827        0.043850
# 21     0.929291          0.029193           0.043118        0.040222
# 22     0.944733          0.021128           0.042999        0.024828
# 23     0.939459          0.024713           0.042068        0.042459
#
#     std_f1_val  std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 0     0.027799                   0.047717         0.046344         0.031226
# 1     0.022986                   0.037665         0.049276         0.034126
# 2     0.022750                   0.040427         0.038743         0.043809
# 3     0.025197                   0.047981         0.042719         0.039452
# 4     0.027956                   0.057254         0.037345         0.039071
# 5     0.028999                   0.052670         0.046106         0.037856
# 6     0.027048                   0.053003         0.043149         0.029146
# 7     0.034274                   0.062798         0.049028         0.045384
# 8     0.029806                   0.050429         0.049124         0.033635
# 9     0.027281                   0.053350         0.044229         0.034419
# 10    0.033618                   0.063543         0.045569         0.039730
# 11    0.030925                   0.059733         0.049801         0.031251
# 12    0.026492                   0.046826         0.049352         0.030380
# 13    0.030510                   0.056187         0.039706         0.037799
# 14    0.028158                   0.052412         0.043976         0.024521
# 15    0.031404                   0.058293         0.043599         0.034072
# 16    0.033910                   0.062615         0.045684         0.034072
# 17    0.025333                   0.037499         0.038558         0.028836
# 18    0.025765                   0.050373         0.050267         0.031795
# 19    0.026128                   0.044801         0.049975         0.025636
# 20    0.030789                   0.058302         0.043850         0.043808
# 21    0.030799                   0.057781         0.040222         0.033874
# 22    0.025267                   0.042768         0.024828         0.034945
# 23    0.025508                   0.049828         0.042459         0.036492

# %%
merge_data.sort_values(by=["specificity", "std_specificity"], ascending=[False, True])[:5]
# Out:
#               Algorithm          Encoder  accuracy_val  precision_val  \
# 17        XGBClassifier  protrans_albert      0.933784       0.953993
# 1   ExtraTrees-ensemble             esme      0.944595       0.953096
# 18  ExtraTrees-ensemble    protrans_bert      0.932432       0.951810
# 8   ExtraTrees-ensemble            esm1b      0.937838       0.949279
# 0   ExtraTrees-ensemble   protrans_xlu50      0.947297       0.950247
#
#     recall_val    f1_val  matthews_corrcoef_val  sensitivity  specificity  \
# 17    0.907706  0.929669               0.867893     0.907706     0.957112
# 1     0.934603  0.942308               0.890885     0.934603     0.955270
# 18    0.911321  0.929894               0.866779     0.911321     0.954840
# 8     0.922948  0.934775               0.876733     0.922948     0.952567
# 0     0.941725  0.945064               0.895236     0.941725     0.952137
#
#     std_accuracy_val  std_precision_val  std_recall_val  std_f1_val  \
# 17          0.018518           0.031333        0.038558    0.025333
# 1           0.019583           0.039155        0.049276    0.022986
# 18          0.025481           0.035637        0.050267    0.025765
# 8           0.025640           0.040170        0.049124    0.029806
# 0           0.024216           0.034597        0.046344    0.027799
#
#     std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 17                   0.037499         0.038558         0.028836
# 1                    0.037665         0.049276         0.034126
# 18                   0.050373         0.050267         0.031795
# 8                    0.050429         0.049124         0.033635
# 0                    0.047717         0.046344         0.031226

# %%
merge_data.sort_values(by=["sensitivity", "std_sensitivity"], ascending=[False, True])[:5]
# Out:
#                          Algorithm        Encoder  accuracy_val  \
# 2        GaussianProcessClassifier   protrans_bdf      0.941892
# 10                 RidgeClassifier   protrans_bdf      0.936486
# 9               LogisticRegression          esm1b      0.937838
# 5   HistGradientBoostingClassifier  protrans_bert      0.939189
# 3                   LGBMClassifier  protrans_bert      0.941892
#
#     precision_val  recall_val    f1_val  matthews_corrcoef_val  sensitivity  \
# 2        0.928998    0.957015  0.941603               0.885454     0.957015
# 10       0.925017    0.947997  0.935452               0.873968     0.947997
# 9        0.930043    0.945558  0.936842               0.876490     0.945558
# 5        0.934601    0.942519  0.937478               0.879423     0.942519
# 3        0.940419    0.942039  0.940096               0.884849     0.942039
#
#     specificity  std_accuracy_val  std_precision_val  std_recall_val  \
# 2      0.928291          0.021176           0.043068        0.038743
# 10     0.925559          0.031883           0.044913        0.045569
# 9      0.930464          0.026420           0.037386        0.044229
# 5      0.936702          0.026458           0.041710        0.046106
# 3      0.941631          0.023878           0.042199        0.042719
#
#     std_f1_val  std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 2     0.022750                   0.040427         0.038743         0.043809
# 10    0.033618                   0.063543         0.045569         0.039730
# 9     0.027281                   0.053350         0.044229         0.034419
# 5     0.028999                   0.052670         0.046106         0.037856
# 3     0.025197                   0.047981         0.042719         0.039452

# %%
merge_data.sort_values(by=["matthews_corrcoef_val", "std_matthews_corrcoef_val"], ascending=[False, True])[:5]
# Out:
#                    Algorithm         Encoder  accuracy_val  precision_val  \
# 0        ExtraTrees-ensemble  protrans_xlu50      0.947297       0.950247
# 1        ExtraTrees-ensemble            esme      0.944595       0.953096
# 2  GaussianProcessClassifier    protrans_bdf      0.941892       0.928998
# 3             LGBMClassifier   protrans_bert      0.941892       0.940419
# 4         LogisticRegression    protrans_bdf      0.941892       0.942590
#
#    recall_val    f1_val  matthews_corrcoef_val  sensitivity  specificity  \
# 0    0.941725  0.945064               0.895236     0.941725     0.952137
# 1    0.934603  0.942308               0.890885     0.934603     0.955270
# 2    0.957015  0.941603               0.885454     0.957015     0.928291
# 3    0.942039  0.940096               0.884849     0.942039     0.941631
# 4    0.940846  0.940945               0.884222     0.940846     0.944131
#
#    std_accuracy_val  std_precision_val  std_recall_val  std_f1_val  \
# 0          0.024216           0.034597        0.046344    0.027799
# 1          0.019583           0.039155        0.049276    0.022986
# 2          0.021176           0.043068        0.038743    0.022750
# 3          0.023878           0.042199        0.042719    0.025197
# 4          0.028525           0.041751        0.037345    0.027956
#
#    std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 0                   0.047717         0.046344         0.031226
# 1                   0.037665         0.049276         0.034126
# 2                   0.040427         0.038743         0.043809
# 3                   0.047981         0.042719         0.039452
# 4                   0.057254         0.037345         0.039071

# %%
merge_data.sort_values(by=["f1_val", "std_f1_val"], ascending=[False, True])[:5]
# Out:
#                    Algorithm         Encoder  accuracy_val  precision_val  \
# 0        ExtraTrees-ensemble  protrans_xlu50      0.947297       0.950247
# 1        ExtraTrees-ensemble            esme      0.944595       0.953096
# 2  GaussianProcessClassifier    protrans_bdf      0.941892       0.928998
# 4         LogisticRegression    protrans_bdf      0.941892       0.942590
# 3             LGBMClassifier   protrans_bert      0.941892       0.940419
#
#    recall_val    f1_val  matthews_corrcoef_val  sensitivity  specificity  \
# 0    0.941725  0.945064               0.895236     0.941725     0.952137
# 1    0.934603  0.942308               0.890885     0.934603     0.955270
# 2    0.957015  0.941603               0.885454     0.957015     0.928291
# 4    0.940846  0.940945               0.884222     0.940846     0.944131
# 3    0.942039  0.940096               0.884849     0.942039     0.941631
#
#    std_accuracy_val  std_precision_val  std_recall_val  std_f1_val  \
# 0          0.024216           0.034597        0.046344    0.027799
# 1          0.019583           0.039155        0.049276    0.022986
# 2          0.021176           0.043068        0.038743    0.022750
# 4          0.028525           0.041751        0.037345    0.027956
# 3          0.023878           0.042199        0.042719    0.025197
#
#    std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 0                   0.047717         0.046344         0.031226
# 1                   0.037665         0.049276         0.034126
# 2                   0.040427         0.038743         0.043809
# 4                   0.057254         0.037345         0.039071
# 3                   0.047981         0.042719         0.039452

# %%
merge_data.sort_values(by=["recall_val", "std_recall_val"], ascending=[False, True])[:5]
# Out:
#                          Algorithm        Encoder  accuracy_val  \
# 2        GaussianProcessClassifier   protrans_bdf      0.941892
# 10                 RidgeClassifier   protrans_bdf      0.936486
# 9               LogisticRegression          esm1b      0.937838
# 5   HistGradientBoostingClassifier  protrans_bert      0.939189
# 3                   LGBMClassifier  protrans_bert      0.941892
#
#     precision_val  recall_val    f1_val  matthews_corrcoef_val  sensitivity  \
# 2        0.928998    0.957015  0.941603               0.885454     0.957015
# 10       0.925017    0.947997  0.935452               0.873968     0.947997
# 9        0.930043    0.945558  0.936842               0.876490     0.945558
# 5        0.934601    0.942519  0.937478               0.879423     0.942519
# 3        0.940419    0.942039  0.940096               0.884849     0.942039
#
#     specificity  std_accuracy_val  std_precision_val  std_recall_val  \
# 2      0.928291          0.021176           0.043068        0.038743
# 10     0.925559          0.031883           0.044913        0.045569
# 9      0.930464          0.026420           0.037386        0.044229
# 5      0.936702          0.026458           0.041710        0.046106
# 3      0.941631          0.023878           0.042199        0.042719
#
#     std_f1_val  std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 2     0.022750                   0.040427         0.038743         0.043809
# 10    0.033618                   0.063543         0.045569         0.039730
# 9     0.027281                   0.053350         0.044229         0.034419
# 5     0.028999                   0.052670         0.046106         0.037856
# 3     0.025197                   0.047981         0.042719         0.039452

# %%
merge_data.sort_values(by=["precision_val", "std_precision_val"], ascending=[False, True])[:5]
# Out:
#               Algorithm          Encoder  accuracy_val  precision_val  \
# 17        XGBClassifier  protrans_albert      0.933784       0.953993
# 1   ExtraTrees-ensemble             esme      0.944595       0.953096
# 18  ExtraTrees-ensemble    protrans_bert      0.932432       0.951810
# 0   ExtraTrees-ensemble   protrans_xlu50      0.947297       0.950247
# 8   ExtraTrees-ensemble            esm1b      0.937838       0.949279
#
#     recall_val    f1_val  matthews_corrcoef_val  sensitivity  specificity  \
# 17    0.907706  0.929669               0.867893     0.907706     0.957112
# 1     0.934603  0.942308               0.890885     0.934603     0.955270
# 18    0.911321  0.929894               0.866779     0.911321     0.954840
# 0     0.941725  0.945064               0.895236     0.941725     0.952137
# 8     0.922948  0.934775               0.876733     0.922948     0.952567
#
#     std_accuracy_val  std_precision_val  std_recall_val  std_f1_val  \
# 17          0.018518           0.031333        0.038558    0.025333
# 1           0.019583           0.039155        0.049276    0.022986
# 18          0.025481           0.035637        0.050267    0.025765
# 0           0.024216           0.034597        0.046344    0.027799
# 8           0.025640           0.040170        0.049124    0.029806
#
#     std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 17                   0.037499         0.038558         0.028836
# 1                    0.037665         0.049276         0.034126
# 18                   0.050373         0.050267         0.031795
# 0                    0.047717         0.046344         0.031226
# 8                    0.050429         0.049124         0.033635

# %%
merge_data.sort_values(by=["accuracy_val", "std_accuracy_val"], ascending=[False, True])[:5]
# Out:
#                    Algorithm         Encoder  accuracy_val  precision_val  \
# 0        ExtraTrees-ensemble  protrans_xlu50      0.947297       0.950247
# 1        ExtraTrees-ensemble            esme      0.944595       0.953096
# 2  GaussianProcessClassifier    protrans_bdf      0.941892       0.928998
# 3             LGBMClassifier   protrans_bert      0.941892       0.940419
# 4         LogisticRegression    protrans_bdf      0.941892       0.942590
#
#    recall_val    f1_val  matthews_corrcoef_val  sensitivity  specificity  \
# 0    0.941725  0.945064               0.895236     0.941725     0.952137
# 1    0.934603  0.942308               0.890885     0.934603     0.955270
# 2    0.957015  0.941603               0.885454     0.957015     0.928291
# 3    0.942039  0.940096               0.884849     0.942039     0.941631
# 4    0.940846  0.940945               0.884222     0.940846     0.944131
#
#    std_accuracy_val  std_precision_val  std_recall_val  std_f1_val  \
# 0          0.024216           0.034597        0.046344    0.027799
# 1          0.019583           0.039155        0.049276    0.022986
# 2          0.021176           0.043068        0.038743    0.022750
# 3          0.023878           0.042199        0.042719    0.025197
# 4          0.028525           0.041751        0.037345    0.027956
#
#    std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 0                   0.047717         0.046344         0.031226
# 1                   0.037665         0.049276         0.034126
# 2                   0.040427         0.038743         0.043809
# 3                   0.047981         0.042719         0.039452
# 4                   0.057254         0.037345         0.039071
