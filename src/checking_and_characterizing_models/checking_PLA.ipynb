# %%
import pandas as pd

# %%
df_performances = pd.read_csv("../../results_training_exploring/PLA/explored_performances.csv")
df_selected = pd.read_csv("../../results_training_exploring/PLA/selected_models_for_tuning.csv")

df_merge = df_selected.merge(right=df_performances, left_on=['Algorithm','Encoder'], right_on=["algorithm", "encoder"])
df_merge.columns
# Out:
# Index(['Algorithm', 'Encoder', 'mean_accuracy_training_x',
#        'mean_f_score_training_x', 'mean_precision_training_x',
#        'mean_recall_training_x', 'mean_accuracy_testing_x',
#        'mean_f_score_testing_x', 'mean_precision_testing_x',
#        'mean_recall_testing_x', 'mean_accuracy_testing_y',
#        'mean_f_score_testing_y', 'mean_precision_testing_y',
#        'mean_recall_testing_y', 'mean_accuracy_training_y',
#        'mean_f_score_training_y', 'mean_precision_training_y',
#        'mean_recall_training_y', 'Voting', 'algorithm', 'fit_time',
#        'score_time', 'F1_cv', 'recall_cv', 'precision_cv', 'accuracy_cv',
#        'accuracy_val', 'precision_val', 'recall_val', 'f1_val',
#        'matthews_corrcoef_val', 'sensitivity', 'specificity', 'encoder',
#        'Strategy'],
#       dtype='object')

# %%
df_merge = df_merge[['Algorithm', 'Encoder', 'F1_cv', 'recall_cv', 'precision_cv', 'accuracy_cv',
       'accuracy_val', 'precision_val', 'recall_val', 'f1_val', 'matthews_corrcoef_val', 'sensitivity', 'specificity', 'Strategy']]

df_merge
# Out:
#                         Algorithm  Encoder     F1_cv  recall_cv  precision_cv  \
# 0  HistGradientBoostingClassifier  plusrnn  0.807866   0.808824      0.816863
# 1  HistGradientBoostingClassifier  plusrnn  0.780439   0.786029      0.814022
# 2  HistGradientBoostingClassifier  plusrnn  0.766233   0.774265      0.804822
# 3  HistGradientBoostingClassifier  plusrnn  0.828726   0.832353      0.841064
# 4  HistGradientBoostingClassifier  plusrnn  0.808497   0.808824      0.818235
# 5  HistGradientBoostingClassifier  plusrnn  0.855429   0.857353      0.866878
# 6  HistGradientBoostingClassifier  plusrnn  0.835951   0.843382      0.878856
# 7  HistGradientBoostingClassifier  plusrnn  0.780794   0.783824      0.795961
# 8  HistGradientBoostingClassifier  plusrnn  0.857026   0.857353      0.861050
# 9  HistGradientBoostingClassifier  plusrnn  0.745587   0.748529      0.762317
#
#    accuracy_cv  accuracy_val  precision_val  recall_val    f1_val  \
# 0     0.808824      0.818182       0.750000    0.900000  0.818182
# 1     0.786029      0.681818       0.636364    0.700000  0.666667
# 2     0.774265      0.909091       0.923077    0.923077  0.923077
# 3     0.832353      0.909091       0.857143    1.000000  0.923077
# 4     0.808824      0.727273       0.666667    0.909091  0.769231
# 5     0.857353      0.772727       0.615385    1.000000  0.761905
# 6     0.843382      0.818182       0.888889    0.727273  0.800000
# 7     0.783824      0.818182       0.777778    0.777778  0.777778
# 8     0.857353      0.863636       0.857143    0.923077  0.888889
# 9     0.748529      0.818182       0.727273    0.888889  0.800000
#
#    matthews_corrcoef_val  sensitivity  specificity         Strategy
# 0               0.650000     0.900000     0.750000  Embedding-based
# 1               0.365148     0.700000     0.666667  Embedding-based
# 2               0.811966     0.923077     0.888889  Embedding-based
# 3               0.828079     1.000000     0.800000  Embedding-based
# 4               0.487950     0.909091     0.545455  Embedding-based
# 5               0.628971     1.000000     0.642857  Embedding-based
# 6               0.647150     0.727273     0.909091  Embedding-based
# 7               0.623932     0.777778     0.846154  Embedding-based
# 8               0.716328     0.923077     0.777778  Embedding-based
# 9               0.647150     0.888889     0.769231  Embedding-based

# %%
df_merge.groupby(by=['Algorithm', 'Encoder']).mean(numeric_only=True).sort_values(by="matthews_corrcoef_val", ascending=False)
# Out:
#                                            F1_cv  recall_cv  precision_cv  \
# Algorithm                      Encoder
# HistGradientBoostingClassifier plusrnn  0.806655   0.810074      0.826007
#
#                                         accuracy_cv  accuracy_val  \
# Algorithm                      Encoder
# HistGradientBoostingClassifier plusrnn     0.810074      0.813636
#
#                                         precision_val  recall_val   f1_val  \
# Algorithm                      Encoder
# HistGradientBoostingClassifier plusrnn       0.769972    0.874918  0.81288
#
#                                         matthews_corrcoef_val  sensitivity  \
# Algorithm                      Encoder
# HistGradientBoostingClassifier plusrnn               0.640667     0.874918
#
#                                         specificity
# Algorithm                      Encoder
# HistGradientBoostingClassifier plusrnn     0.759612

# %%
df_merge.groupby(by=['Algorithm', 'Encoder']).std(numeric_only=True).sort_values(by="matthews_corrcoef_val", ascending=False)
# Out:
#                                            F1_cv  recall_cv  precision_cv  \
# Algorithm                      Encoder
# HistGradientBoostingClassifier plusrnn  0.037985   0.037144      0.035922
#
#                                         accuracy_cv  accuracy_val  \
# Algorithm                      Encoder
# HistGradientBoostingClassifier plusrnn     0.037144      0.072506
#
#                                         precision_val  recall_val    f1_val  \
# Algorithm                      Encoder
# HistGradientBoostingClassifier plusrnn       0.109282    0.105279  0.079957
#
#                                         matthews_corrcoef_val  sensitivity  \
# Algorithm                      Encoder
# HistGradientBoostingClassifier plusrnn               0.137442     0.105279
#
#                                         specificity
# Algorithm                      Encoder
# HistGradientBoostingClassifier plusrnn     0.113933
