# %%
import pandas as pd

# %%
df_performances = pd.read_csv("../../results_training_exploring/NYLON_PA/explored_performances.csv")
df_selected = pd.read_csv("../../results_training_exploring/NYLON_PA/selected_models_for_tuning.csv")

df_merge = df_selected.merge(right=df_performances, left_on=['Algorithm','Encoder'], right_on=["algorithm", "encoder"])
df_merge.columns
# Out:
# Index(['Algorithm', 'Encoder', 'mean_accuracy_training_x',
#        'mean_f_score_training_x', 'mean_precision_training_x',
#        'mean_recall_training_x', 'mean_accuracy_testing_x',
#        'mean_f_score_testing_x', 'mean_precision_testing_x',
#        'mean_recall_testing_x', 'mean_accuracy_testing_y',
#        'mean_f_score_testing_y', 'mean_precision_testing_y',
#        'mean_recall_testing_y', 'mean_accuracy_training_y',
#        'mean_f_score_training_y', 'mean_precision_training_y',
#        'mean_recall_training_y', 'Voting', 'algorithm', 'fit_time',
#        'score_time', 'F1_cv', 'recall_cv', 'precision_cv', 'accuracy_cv',
#        'accuracy_val', 'precision_val', 'recall_val', 'f1_val',
#        'matthews_corrcoef_val', 'sensitivity', 'specificity', 'encoder',
#        'Strategy'],
#       dtype='object')

# %%
df_merge = df_merge[['Algorithm', 'Encoder', 'F1_cv', 'recall_cv', 'precision_cv', 'accuracy_cv',
       'accuracy_val', 'precision_val', 'recall_val', 'f1_val', 'matthews_corrcoef_val', 'sensitivity', 'specificity', 'Strategy']]

df_merge.head(5)
# Out:
#              Algorithm Encoder     F1_cv  recall_cv  precision_cv  \
# 0  ExtraTrees-ensemble   esm1b  0.940659   0.940659      0.940659
# 1  ExtraTrees-ensemble   esm1b  0.984429   0.984615      0.986538
# 2  ExtraTrees-ensemble   esm1b  0.957216   0.957143      0.959184
# 3  ExtraTrees-ensemble   esm1b  0.971282   0.971429      0.975000
# 4  ExtraTrees-ensemble   esm1b  0.941499   0.941758      0.949294
#
#    accuracy_cv  accuracy_val  precision_val  recall_val    f1_val  \
# 0     0.940659      0.944444       0.888889    1.000000  0.941176
# 1     0.984615      0.944444       1.000000    0.909091  0.952381
# 2     0.957143      0.888889       1.000000    0.833333  0.909091
# 3     0.971429      0.944444       0.875000    1.000000  0.933333
# 4     0.941758      0.944444       0.875000    1.000000  0.933333
#
#    matthews_corrcoef_val  sensitivity  specificity         Strategy
# 0               0.894427     1.000000     0.900000  Embedding-based
# 1               0.891883     0.909091     1.000000  Embedding-based
# 2               0.790569     0.833333     1.000000  Embedding-based
# 3               0.891883     1.000000     0.909091  Embedding-based
# 4               0.891883     1.000000     0.909091  Embedding-based

# %%
grouped_data = df_merge.groupby(by=['Algorithm', 'Encoder']).mean(numeric_only=True).sort_values(by="matthews_corrcoef_val", ascending=False).reset_index()

# %%
grouped_std = df_merge.groupby(by=['Algorithm', 'Encoder']).std(numeric_only=True).sort_values(by="matthews_corrcoef_val", ascending=True).reset_index()

# %%
grouped_data = grouped_data[["Algorithm", "Encoder", "accuracy_val", "precision_val", "recall_val", "f1_val", "matthews_corrcoef_val", "sensitivity", "specificity"]]
grouped_std = grouped_std[["Algorithm", "Encoder", "accuracy_val", "precision_val", "recall_val", "f1_val", "matthews_corrcoef_val", "sensitivity", "specificity"]]
grouped_std.columns = ["Algorithm", "Encoder", "std_accuracy_val", "std_precision_val", "std_recall_val", "std_f1_val", "std_matthews_corrcoef_val", "std_sensitivity", "std_specificity"]

# %%
merge_data = grouped_data.merge(right=grouped_std, on=["Algorithm", "Encoder"])
merge_data
# Out:
#                         Algorithm         Encoder  accuracy_val  \
# 0             ExtraTrees-ensemble            esme      0.972222
# 1          RandomForestClassifier  protrans_xlu50      0.972222
# 2                             SVC    protrans_bdf      0.961111
# 3  HistGradientBoostingClassifier  protrans_xlu50      0.955556
# 4             ExtraTrees-ensemble           esm1b      0.955556
#
#    precision_val  recall_val    f1_val  matthews_corrcoef_val  sensitivity  \
# 0       0.988889    0.963485  0.974983               0.945902     0.963485
# 1       0.987500    0.963485  0.974199               0.945648     0.963485
# 2       0.963889    0.963485  0.961650               0.924279     0.963485
# 3       0.963889    0.954394  0.956411               0.914863     0.954394
# 4       0.963889    0.955152  0.956906               0.914695     0.955152
#
#    specificity  std_accuracy_val  std_precision_val  std_recall_val  \
# 0     0.990000          0.029280           0.035136        0.047305
# 1     0.990909          0.029280           0.039528        0.047305
# 2     0.971818          0.026836           0.058267        0.047305
# 3     0.971818          0.035136           0.058267        0.064522
# 4     0.971818          0.035136           0.058267        0.061638
#
#    std_f1_val  std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 0    0.026661                   0.057066         0.047305         0.031623
# 1    0.027855                   0.057326         0.047305         0.028748
# 2    0.027562                   0.052298         0.047305         0.045444
# 3    0.033793                   0.065571         0.064522         0.045444
# 4    0.032229                   0.066784         0.061638         0.045444

# %%
merge_data.columns
# Out:
# Index(['Algorithm', 'Encoder', 'accuracy_val', 'precision_val', 'recall_val',
#        'f1_val', 'matthews_corrcoef_val', 'sensitivity', 'specificity',
#        'std_accuracy_val', 'std_precision_val', 'std_recall_val', 'std_f1_val',
#        'std_matthews_corrcoef_val', 'std_sensitivity', 'std_specificity'],
#       dtype='object')

# %%
merge_data.sort_values(by=["specificity", "std_specificity"], ascending=[False, True])
# Out:
#                         Algorithm         Encoder  accuracy_val  \
# 1          RandomForestClassifier  protrans_xlu50      0.972222
# 0             ExtraTrees-ensemble            esme      0.972222
# 3  HistGradientBoostingClassifier  protrans_xlu50      0.955556
# 2                             SVC    protrans_bdf      0.961111
# 4             ExtraTrees-ensemble           esm1b      0.955556
#
#    precision_val  recall_val    f1_val  matthews_corrcoef_val  sensitivity  \
# 1       0.987500    0.963485  0.974199               0.945648     0.963485
# 0       0.988889    0.963485  0.974983               0.945902     0.963485
# 3       0.963889    0.954394  0.956411               0.914863     0.954394
# 2       0.963889    0.963485  0.961650               0.924279     0.963485
# 4       0.963889    0.955152  0.956906               0.914695     0.955152
#
#    specificity  std_accuracy_val  std_precision_val  std_recall_val  \
# 1     0.990909          0.029280           0.039528        0.047305
# 0     0.990000          0.029280           0.035136        0.047305
# 3     0.971818          0.035136           0.058267        0.064522
# 2     0.971818          0.026836           0.058267        0.047305
# 4     0.971818          0.035136           0.058267        0.061638
#
#    std_f1_val  std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 1    0.027855                   0.057326         0.047305         0.028748
# 0    0.026661                   0.057066         0.047305         0.031623
# 3    0.033793                   0.065571         0.064522         0.045444
# 2    0.027562                   0.052298         0.047305         0.045444
# 4    0.032229                   0.066784         0.061638         0.045444

# %%
merge_data.sort_values(by=["sensitivity", "std_sensitivity"], ascending=[False, True])
# Out:
#                         Algorithm         Encoder  accuracy_val  \
# 0             ExtraTrees-ensemble            esme      0.972222
# 1          RandomForestClassifier  protrans_xlu50      0.972222
# 2                             SVC    protrans_bdf      0.961111
# 4             ExtraTrees-ensemble           esm1b      0.955556
# 3  HistGradientBoostingClassifier  protrans_xlu50      0.955556
#
#    precision_val  recall_val    f1_val  matthews_corrcoef_val  sensitivity  \
# 0       0.988889    0.963485  0.974983               0.945902     0.963485
# 1       0.987500    0.963485  0.974199               0.945648     0.963485
# 2       0.963889    0.963485  0.961650               0.924279     0.963485
# 4       0.963889    0.955152  0.956906               0.914695     0.955152
# 3       0.963889    0.954394  0.956411               0.914863     0.954394
#
#    specificity  std_accuracy_val  std_precision_val  std_recall_val  \
# 0     0.990000          0.029280           0.035136        0.047305
# 1     0.990909          0.029280           0.039528        0.047305
# 2     0.971818          0.026836           0.058267        0.047305
# 4     0.971818          0.035136           0.058267        0.061638
# 3     0.971818          0.035136           0.058267        0.064522
#
#    std_f1_val  std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 0    0.026661                   0.057066         0.047305         0.031623
# 1    0.027855                   0.057326         0.047305         0.028748
# 2    0.027562                   0.052298         0.047305         0.045444
# 4    0.032229                   0.066784         0.061638         0.045444
# 3    0.033793                   0.065571         0.064522         0.045444

# %%
merge_data.sort_values(by=["matthews_corrcoef_val", "std_matthews_corrcoef_val"], ascending=[False, True])
# Out:
#                         Algorithm         Encoder  accuracy_val  \
# 0             ExtraTrees-ensemble            esme      0.972222
# 1          RandomForestClassifier  protrans_xlu50      0.972222
# 2                             SVC    protrans_bdf      0.961111
# 3  HistGradientBoostingClassifier  protrans_xlu50      0.955556
# 4             ExtraTrees-ensemble           esm1b      0.955556
#
#    precision_val  recall_val    f1_val  matthews_corrcoef_val  sensitivity  \
# 0       0.988889    0.963485  0.974983               0.945902     0.963485
# 1       0.987500    0.963485  0.974199               0.945648     0.963485
# 2       0.963889    0.963485  0.961650               0.924279     0.963485
# 3       0.963889    0.954394  0.956411               0.914863     0.954394
# 4       0.963889    0.955152  0.956906               0.914695     0.955152
#
#    specificity  std_accuracy_val  std_precision_val  std_recall_val  \
# 0     0.990000          0.029280           0.035136        0.047305
# 1     0.990909          0.029280           0.039528        0.047305
# 2     0.971818          0.026836           0.058267        0.047305
# 3     0.971818          0.035136           0.058267        0.064522
# 4     0.971818          0.035136           0.058267        0.061638
#
#    std_f1_val  std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 0    0.026661                   0.057066         0.047305         0.031623
# 1    0.027855                   0.057326         0.047305         0.028748
# 2    0.027562                   0.052298         0.047305         0.045444
# 3    0.033793                   0.065571         0.064522         0.045444
# 4    0.032229                   0.066784         0.061638         0.045444

# %%
merge_data.sort_values(by=["f1_val", "std_f1_val"], ascending=[False, True])
# Out:
#                         Algorithm         Encoder  accuracy_val  \
# 0             ExtraTrees-ensemble            esme      0.972222
# 1          RandomForestClassifier  protrans_xlu50      0.972222
# 2                             SVC    protrans_bdf      0.961111
# 4             ExtraTrees-ensemble           esm1b      0.955556
# 3  HistGradientBoostingClassifier  protrans_xlu50      0.955556
#
#    precision_val  recall_val    f1_val  matthews_corrcoef_val  sensitivity  \
# 0       0.988889    0.963485  0.974983               0.945902     0.963485
# 1       0.987500    0.963485  0.974199               0.945648     0.963485
# 2       0.963889    0.963485  0.961650               0.924279     0.963485
# 4       0.963889    0.955152  0.956906               0.914695     0.955152
# 3       0.963889    0.954394  0.956411               0.914863     0.954394
#
#    specificity  std_accuracy_val  std_precision_val  std_recall_val  \
# 0     0.990000          0.029280           0.035136        0.047305
# 1     0.990909          0.029280           0.039528        0.047305
# 2     0.971818          0.026836           0.058267        0.047305
# 4     0.971818          0.035136           0.058267        0.061638
# 3     0.971818          0.035136           0.058267        0.064522
#
#    std_f1_val  std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 0    0.026661                   0.057066         0.047305         0.031623
# 1    0.027855                   0.057326         0.047305         0.028748
# 2    0.027562                   0.052298         0.047305         0.045444
# 4    0.032229                   0.066784         0.061638         0.045444
# 3    0.033793                   0.065571         0.064522         0.045444

# %%
merge_data.sort_values(by=["recall_val", "std_recall_val"], ascending=[False, True])
# Out:
#                         Algorithm         Encoder  accuracy_val  \
# 0             ExtraTrees-ensemble            esme      0.972222
# 1          RandomForestClassifier  protrans_xlu50      0.972222
# 2                             SVC    protrans_bdf      0.961111
# 4             ExtraTrees-ensemble           esm1b      0.955556
# 3  HistGradientBoostingClassifier  protrans_xlu50      0.955556
#
#    precision_val  recall_val    f1_val  matthews_corrcoef_val  sensitivity  \
# 0       0.988889    0.963485  0.974983               0.945902     0.963485
# 1       0.987500    0.963485  0.974199               0.945648     0.963485
# 2       0.963889    0.963485  0.961650               0.924279     0.963485
# 4       0.963889    0.955152  0.956906               0.914695     0.955152
# 3       0.963889    0.954394  0.956411               0.914863     0.954394
#
#    specificity  std_accuracy_val  std_precision_val  std_recall_val  \
# 0     0.990000          0.029280           0.035136        0.047305
# 1     0.990909          0.029280           0.039528        0.047305
# 2     0.971818          0.026836           0.058267        0.047305
# 4     0.971818          0.035136           0.058267        0.061638
# 3     0.971818          0.035136           0.058267        0.064522
#
#    std_f1_val  std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 0    0.026661                   0.057066         0.047305         0.031623
# 1    0.027855                   0.057326         0.047305         0.028748
# 2    0.027562                   0.052298         0.047305         0.045444
# 4    0.032229                   0.066784         0.061638         0.045444
# 3    0.033793                   0.065571         0.064522         0.045444

# %%
merge_data.sort_values(by=["precision_val", "std_precision_val"], ascending=[False, True])
# Out:
#                         Algorithm         Encoder  accuracy_val  \
# 0             ExtraTrees-ensemble            esme      0.972222
# 1          RandomForestClassifier  protrans_xlu50      0.972222
# 4             ExtraTrees-ensemble           esm1b      0.955556
# 2                             SVC    protrans_bdf      0.961111
# 3  HistGradientBoostingClassifier  protrans_xlu50      0.955556
#
#    precision_val  recall_val    f1_val  matthews_corrcoef_val  sensitivity  \
# 0       0.988889    0.963485  0.974983               0.945902     0.963485
# 1       0.987500    0.963485  0.974199               0.945648     0.963485
# 4       0.963889    0.955152  0.956906               0.914695     0.955152
# 2       0.963889    0.963485  0.961650               0.924279     0.963485
# 3       0.963889    0.954394  0.956411               0.914863     0.954394
#
#    specificity  std_accuracy_val  std_precision_val  std_recall_val  \
# 0     0.990000          0.029280           0.035136        0.047305
# 1     0.990909          0.029280           0.039528        0.047305
# 4     0.971818          0.035136           0.058267        0.061638
# 2     0.971818          0.026836           0.058267        0.047305
# 3     0.971818          0.035136           0.058267        0.064522
#
#    std_f1_val  std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 0    0.026661                   0.057066         0.047305         0.031623
# 1    0.027855                   0.057326         0.047305         0.028748
# 4    0.032229                   0.066784         0.061638         0.045444
# 2    0.027562                   0.052298         0.047305         0.045444
# 3    0.033793                   0.065571         0.064522         0.045444

# %%
merge_data.sort_values(by=["accuracy_val", "std_accuracy_val"], ascending=[False, True])
# Out:
#                         Algorithm         Encoder  accuracy_val  \
# 1          RandomForestClassifier  protrans_xlu50      0.972222
# 0             ExtraTrees-ensemble            esme      0.972222
# 2                             SVC    protrans_bdf      0.961111
# 4             ExtraTrees-ensemble           esm1b      0.955556
# 3  HistGradientBoostingClassifier  protrans_xlu50      0.955556
#
#    precision_val  recall_val    f1_val  matthews_corrcoef_val  sensitivity  \
# 1       0.987500    0.963485  0.974199               0.945648     0.963485
# 0       0.988889    0.963485  0.974983               0.945902     0.963485
# 2       0.963889    0.963485  0.961650               0.924279     0.963485
# 4       0.963889    0.955152  0.956906               0.914695     0.955152
# 3       0.963889    0.954394  0.956411               0.914863     0.954394
#
#    specificity  std_accuracy_val  std_precision_val  std_recall_val  \
# 1     0.990909          0.029280           0.039528        0.047305
# 0     0.990000          0.029280           0.035136        0.047305
# 2     0.971818          0.026836           0.058267        0.047305
# 4     0.971818          0.035136           0.058267        0.061638
# 3     0.971818          0.035136           0.058267        0.064522
#
#    std_f1_val  std_matthews_corrcoef_val  std_sensitivity  std_specificity
# 1    0.027855                   0.057326         0.047305         0.028748
# 0    0.026661                   0.057066         0.047305         0.031623
# 2    0.027562                   0.052298         0.047305         0.045444
# 4    0.032229                   0.066784         0.061638         0.045444
# 3    0.033793                   0.065571         0.064522         0.045444
